# %%
import wikipedia as wk

# %% [markdown]
# Plan to conduct this project into three steps:
# 1. Text Classification. In this one I plan to choose RNN, LSTM and other possible models
# 2. After successfully classified the text labels, then I plan to use semi supervised learning. By adding labels for some of these text data, I run semi supervised learning and predict all the text data.
# 3. Then I would try unsupervised learning and generate labels directly from text.

# %%
KB = wk.page("Kobe Bryant")
dataset = KB.content.split(' ')

# %%
for i,link in enumerate(KB.links):
    index = KB.content.index('Harrison Barnes')
    start = index
    end = index
    while KB.content[start] not in '!.?(){}[]<>':
        start -= 1
    while KB.content[end] not in '!.?(){}[]<>':
        end += 1
    if i > 10: 
        break;
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e68a4a0f3a34> in <module>()
#       1 for i,link in enumerate(KB.links):
# ----> 2     index = KB.content.index('Harrison Barnes')
#       3     start = index
#       4     end = index
#       5     while KB.content[start] not in '!.?(){}[]<>':
#
# ValueError: substring not found

# %%
'Joe Bryant' in KB.links
# Out:
# True

# %%
for c in a:
    a.remove(c) m

# %%
a
# Out:
# [2, 4]

# %%
a = 'abc'
b = 'abc'

# %%
a == b
# Out:
# True

# %%
import inspect

# %%
inspect.getmembers(KB)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-6cfae77b07de> in <module>()
# ----> 1 inspect.getmembers(KB)
#
# ~/anaconda3/lib/python3.6/inspect.py in getmembers(object, predicate)
#     340         # looking in the __dict__.
#     341         try:
# --> 342             value = getattr(object, key)
#     343             # handle the duplicate key
#     344             if key in processed:
#
# ~/anaconda3/lib/python3.6/site-packages/wikipedia/wikipedia.py in coordinates(self)
#     568
#     569       if 'query' in request:
# --> 570         coordinates = request['query']['pages'][self.pageid]['coordinates']
#     571         self._coordinates = (Decimal(coordinates[0]['lat']), Decimal(coordinates[0]['lon']))
#     572       else:
#
# KeyError: 'coordinates'

# %%
KB.links
# Out:
# ['1949 BAA Finals',
#  '1950 NBA Finals',
#  '1952 NBA Finals',
#  '1953 NBA Finals',
#  '1954 NBA Finals',
#  '1961–62 NBA season',
#  '1963–64 NBA season',
#  '1969 NBA Finals',
#  '1972 NBA Finals',
#  '1980 NBA Finals',
#  '1982 NBA Finals',
#  '1985 NBA Finals',
#  '1987 NBA Finals',
#  '1988 NBA Finals',
#  '1990 NBA Finals',
#  '1995 NBA draft',
#  '1996 NBA Playoffs',
#  '1996 NBA draft',
#  '1996–97 Charlotte Hornets season',
#  '1996–97 Los Angeles Lakers season',
#  '1996–97 NBA season',
#  '1996–97 Utah Jazz season',
#  '1997 NBA All-Star Game',
#  '1997 NBA Playoffs',
#  '1997–98 Los Angeles Lakers season',
#  '1997–98 NBA season',
#  '1998 NBA All-Star Game',
#  '1998 NBA Playoffs',
#  '1998–99 Los Angeles Lakers season',
#  '1998–99 NBA lockout',
#  '1998–99 NBA season',
#  '1998–99 San Antonio Spurs season',
#  '1999 NBA Playoffs',
#  '1999–2000 Indiana Pacers season',
#  '1999–2000 Los Angeles Lakers season',
#  '1999–2000 NBA season',
# ...
